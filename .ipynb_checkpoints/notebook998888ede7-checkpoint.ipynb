# %%
import os
import random
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import L2
# Out:
# 2023-07-23 12:27:36.512712: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-23 12:27:36.669086: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-23 12:27:36.669785: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-23 12:27:37.373739: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 5))

path = "/home/data/Documents/new/flower_photos/daisy/"
for i, ax in enumerate(axes.flat):
    files = random.choices(os.listdir(path), k=6)
    files = [path+file for file in files]
    ax.imshow(plt.imread(files[i]))

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 5))

path = "/kaggle/input/flowers-dataset/train/rose/"
for i, ax in enumerate(axes.flat):
    files = random.choices(os.listdir(path), k=6)
    files = [path+file for file in files]
    ax.imshow(plt.imread(files[i]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       3 path = "/home/data/Documents/new/flower_photos/rose/"
#       4 for i, ax in enumerate(axes.flat):
# ----> 5     files = random.choices(os.listdir(path), k=6)
#       6     files = [path+file for file in files]
#       7     ax.imshow(plt.imread(files[i]))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/data/Documents/new/flower_photos/rose/'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
TARGET_SIZE = (299, 299)
SEED = 42

# %%
train_generator = ImageDataGenerator(
    rescale=1/255.,
    validation_split=0.15)

train_batches = train_generator.flow_from_directory(
    directory="/kaggle/input/flowers-dataset/train/",
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=2336,
    seed=SEED,
    subset='training')

valid_batches=train_generator.flow_from_directory(
    directory="/kaggle/input/flowers-dataset/train/",
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=410,
    seed=SEED,
    subset='validation')
# Out:
# Found 2336 images belonging to 5 classes.
# Found 410 images belonging to 5 classes.

# %%
# x,y_1 = train_batches.next()

# %%
# x.shape

# %%
test_generator = ImageDataGenerator(rescale=1/255.)  

test_batches = test_generator.flow_from_directory(
    directory="/kaggle/input/flowers-dataset",
    target_size=TARGET_SIZE,
    color_mode='rgb',
    batch_size=1,
    classes=['test'],
    seed=SEED,
    shuffle=True)
# Out:
# Found 924 images belonging to 1 classes.

# %%
model = Sequential([
    Conv2D(filters=124, kernel_size=(3,3), strides=(1,1), padding='valid',activation= 'relu', input_shape=[299,299,3]),
    MaxPooling2D((3,3)),
    Dropout(0.3),
    
    Conv2D(filters=64, kernel_size=3, strides=(1,1), padding='valid',activation= 'relu'),
    MaxPooling2D((3,3)),
    Dropout(0.3),
    
    Conv2D(filters=64, kernel_size=3, strides=(1,1), padding='valid',activation= 'relu'),
    MaxPooling2D((3,3)),
    Dropout(0.3),
    
    Conv2D(filters=32, kernel_size=3, strides=(1,1), padding='valid',activation= 'relu'),
    MaxPooling2D((3,3)),
    Dropout(0.3),

    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(5, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 297, 297, 124)     3472
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 124)      0
#  )
#
#  dropout (Dropout)           (None, 99, 99, 124)       0
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 64)        71488
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 30, 30, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 10, 10, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 32)          18464
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 32)          0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 147,509
# Trainable params: 147,509
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_batches,
    validation_data=valid_batches,
    batch_size=32,
    epochs=10
)
# Out:
# Epoch 1/10

# %%
# Import the required libraries
import numpy as np

# Get the number of test samples (total number of test images)
num_test_samples = len(test_batches.filenames)

if num_test_samples == 0:
    print("The test_batches iterator is empty. No test samples left to iterate over.")
else:
    print(f"There are {num_test_samples} test samples available in the test_batches iterator.")

# %%
y = ['daisy','dandelion','rose','sunflower','tulip']

# %%
X, Y = train_batches.next()

# %%
y[np.argmax(model.predict(X)[0])]

# %%
model.predict(X)[0]

# %%
img_n = 11
plt.imshow(X[img_n])
pre = model.predict(X)[img_n]
max_ = np.argmax(pre)
plt.xlabel(f"{y[np.argmax(pre)]}, Accuracy {pre[max_]*100}%")

# %%
#!zip -r file.zip /kaggle/working/saved_model
